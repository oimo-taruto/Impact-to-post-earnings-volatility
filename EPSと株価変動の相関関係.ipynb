# %% [markdown]
# <a href="https://colab.research.google.com/github/oimo-taruto/Impact-to-post-earnings-volatility/blob/main/EPS%E3%81%A8%E6%A0%AA%E4%BE%A1%E5%A4%89%E5%8B%95%E3%81%AE%E7%9B%B8%E9%96%A2%E9%96%A2%E4%BF%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def get_earnings_impact(ticker_symbol):
  try:
    ticker_obj = yf.Ticker(ticker_symbol)

    earnings_dates = ticker_obj.get_earnings_dates()
    earnings_dates_list = [date.date() for date in earnings_dates.index]

    all_data = yf.download(tickers=ticker_symbol, period='max',auto_adjust=False)

    if isinstance(all_data.columns, pd.MultiIndex):
      all_data.columns = all_data.columns.get_level_values(0)

    df=all_data[['Open','High','Low','Close','Adj Close','Volume']].copy()
    df = df.reset_index()
    df['Nextday_Open'] = df['Open'].shift(-1)
    df['Nextday_Close'] = df['Close'].shift(-1)
    df['Volatility'] = (df['Nextday_Close'] - df['Close']) * 100 / df['Close']
    df['Volatility_open'] = (df['Nextday_Open'] - df['Close']) * 100 / df['Close']
    df['Volatility_before_10d']=(df['Close']-df['Close'].shift(-10))*100/df['Close'].shift(-10)
    df['Volatility_after_10d']=(df['Close'].shift(10)-df['Close'])*100/df['Close']

    earnings_dates_dt = pd.to_datetime(earnings_dates_list)
    earnings_data = df[df['Date'].isin(earnings_dates_dt)]

    earnings_volatility = earnings_data['Volatility']

    df_ticker_symbol = pd.DataFrame(earnings_dates)

    earnings_data = earnings_data.reset_index()
    df_ticker_symbol = df_ticker_symbol.reset_index()

    earnings_data['Date'] = pd.to_datetime(earnings_data['Date']).dt.normalize().dt.tz_localize(None)
    df_ticker_symbol['Earnings Date'] = pd.to_datetime(df_ticker_symbol['Earnings Date']).dt.normalize().dt.tz_localize(None)

    merged_df = pd.merge(earnings_data, df_ticker_symbol, left_on='Date', right_on='Earnings Date')
    merged_df = merged_df.drop(columns=['Earnings Date'])
    merged_df.replace([np.inf,-np.inf],np.nan,inplace=True)
    merged_df.dropna(inplace=True)

    merged_df['ticker_symbol'] = ticker_symbol # Add this line to include the ticker symbol

    target_cols=['Surprise(%)','EPS Estimate','Volatility','Volatility_open','Volatility_after_10d','Volatility_before_10d']
    df_corr=merged_df[target_cols].corr()
    display(df_corr.style.background_gradient(cmap='coolwarm',vmin=-1,vmax=1).format("{:.3f}"))

    import statsmodels.api as sm

    x=merged_df['Surprise(%)']
    y=merged_df['Volatility_open']
    y2=merged_df['Volatility_after_10d']
    z=merged_df['Volatility_before_10d']
    x_s=(x-x.mean())/x.std()
    y_s=(y-y.mean())/y.std()
    y2_s=(y2-y2.mean())/y2.std()
    z_s=(z-z.mean())/z.std()

    X=merged_df[['Surprise(%)','Volatility_before_10d']]
    X_s=(X-X.mean())/X.std()
    X_s=sm.add_constant(X_s)
    model=sm.OLS(y_s,X_s).fit(cov_type='HC3')
    model2=sm.OLS(y2_s,X_s).fit(cov_type='HC3')

    from statsmodels.iolib.summary2 import summary_col

    res=summary_col([model,model2],stars=True,float_format='%0.3f',model_names=['Open Volatility','After 10days Volatility'])
    print(res)

    print(model.summary())
    print(model2.summary())

    return merged_df

  except Exception as e:
    print(f"An error occured at {ticker_symbol}:{e}")
    return e

target_tickers=['AAPL','MSFT','GOOGL','AMZN','META','MCD']
results=[]
for s in target_tickers:
  results.append(get_earnings_impact(s))

final_all=pd.concat(results)

import seaborn as sns

sns.set_theme(style="whitegrid")
sns.set_context("paper",font_scale=1.2)
g1=sns.FacetGrid(final_all,col="ticker_symbol",col_wrap=3,height=4,sharex=False,sharey=False)
g1.map(sns.regplot,"Volatility_before_10d","Volatility_open",scatter_kws={'alpha':0.5},line_kws={'color':'blue'})
g1.set_axis_labels("Pre-earnings Volatility(10days)","Post-eranings Volatility(open)")
g1.fig.suptitle("Anomary Verification: Pre-earnings Volatility VS Post-earnings Volatility",y=1.03,fontsize=16,fontweight='bold')
plt.show()

g2=sns.FacetGrid(final_all,col="ticker_symbol",col_wrap=3,height=4,sharex=False,sharey=False)
g2.map(sns.regplot,"Surprise(%)","Volatility_open",scatter_kws={'alpha':0.5},line_kws={'color':'green'})
g2.set_axis_labels("EPS Surprise(%)","Post-eranings Volatility(open)")
g2.fig.suptitle("Influence Verification: EPS Surprise VS Post-earnings Volatility",y=1.03,fontsize=16,fontweight='bold')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <style type="text/css">
# #T_5fc24_row0_col0, #T_5fc24_row1_col1, #T_5fc24_row2_col2, #T_5fc24_row3_col3, #T_5fc24_row4_col4, #T_5fc24_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5fc24_row0_col1, #T_5fc24_row1_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_5fc24_row0_col2, #T_5fc24_row2_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_5fc24_row0_col3, #T_5fc24_row3_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_5fc24_row0_col4, #T_5fc24_row1_col5, #T_5fc24_row4_col0, #T_5fc24_row5_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_5fc24_row0_col5, #T_5fc24_row5_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5fc24_row1_col2, #T_5fc24_row2_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5fc24_row1_col3, #T_5fc24_row3_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_5fc24_row1_col4, #T_5fc24_row4_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5fc24_row2_col3, #T_5fc24_row3_col2 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_5fc24_row2_col4, #T_5fc24_row4_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_5fc24_row2_col5, #T_5fc24_row5_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5fc24_row3_col4, #T_5fc24_row4_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_5fc24_row3_col5, #T_5fc24_row5_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5fc24_row4_col5, #T_5fc24_row5_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# </style>
# <table id="T_5fc24" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fc24_level0_col0" class="col_heading level0 col0" >Surprise(%)</th>
#       <th id="T_5fc24_level0_col1" class="col_heading level0 col1" >EPS Estimate</th>
#       <th id="T_5fc24_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_5fc24_level0_col3" class="col_heading level0 col3" >Volatility_open</th>
#       <th id="T_5fc24_level0_col4" class="col_heading level0 col4" >Volatility_after_10d</th>
#       <th id="T_5fc24_level0_col5" class="col_heading level0 col5" >Volatility_before_10d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fc24_level0_row0" class="row_heading level0 row0" >Surprise(%)</th>
#       <td id="T_5fc24_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_5fc24_row0_col1" class="data row0 col1" >-0.403</td>
#       <td id="T_5fc24_row0_col2" class="data row0 col2" >0.063</td>
#       <td id="T_5fc24_row0_col3" class="data row0 col3" >0.202</td>
#       <td id="T_5fc24_row0_col4" class="data row0 col4" >0.121</td>
#       <td id="T_5fc24_row0_col5" class="data row0 col5" >0.089</td>
#     </tr>
#     <tr>
#       <th id="T_5fc24_level0_row1" class="row_heading level0 row1" >EPS Estimate</th>
#       <td id="T_5fc24_row1_col0" class="data row1 col0" >-0.403</td>
#       <td id="T_5fc24_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_5fc24_row1_col2" class="data row1 col2" >0.007</td>
#       <td id="T_5fc24_row1_col3" class="data row1 col3" >0.021</td>
#       <td id="T_5fc24_row1_col4" class="data row1 col4" >-0.069</td>
#       <td id="T_5fc24_row1_col5" class="data row1 col5" >0.117</td>
#     </tr>
#     <tr>
#       <th id="T_5fc24_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_5fc24_row2_col0" class="data row2 col0" >0.063</td>
#       <td id="T_5fc24_row2_col1" class="data row2 col1" >0.007</td>
#       <td id="T_5fc24_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_5fc24_row2_col3" class="data row2 col3" >0.776</td>
#       <td id="T_5fc24_row2_col4" class="data row2 col4" >0.108</td>
#       <td id="T_5fc24_row2_col5" class="data row2 col5" >-0.609</td>
#     </tr>
#     <tr>
#       <th id="T_5fc24_level0_row3" class="row_heading level0 row3" >Volatility_open</th>
#       <td id="T_5fc24_row3_col0" class="data row3 col0" >0.202</td>
#       <td id="T_5fc24_row3_col1" class="data row3 col1" >0.021</td>
#       <td id="T_5fc24_row3_col2" class="data row3 col2" >0.776</td>
#       <td id="T_5fc24_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_5fc24_row3_col4" class="data row3 col4" >0.136</td>
#       <td id="T_5fc24_row3_col5" class="data row3 col5" >-0.530</td>
#     </tr>
#     <tr>
#       <th id="T_5fc24_level0_row4" class="row_heading level0 row4" >Volatility_after_10d</th>
#       <td id="T_5fc24_row4_col0" class="data row4 col0" >0.121</td>
#       <td id="T_5fc24_row4_col1" class="data row4 col1" >-0.069</td>
#       <td id="T_5fc24_row4_col2" class="data row4 col2" >0.108</td>
#       <td id="T_5fc24_row4_col3" class="data row4 col3" >0.136</td>
#       <td id="T_5fc24_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_5fc24_row4_col5" class="data row4 col5" >-0.084</td>
#     </tr>
#     <tr>
#       <th id="T_5fc24_level0_row5" class="row_heading level0 row5" >Volatility_before_10d</th>
#       <td id="T_5fc24_row5_col0" class="data row5 col0" >0.089</td>
#       <td id="T_5fc24_row5_col1" class="data row5 col1" >0.117</td>
#       <td id="T_5fc24_row5_col2" class="data row5 col2" >-0.609</td>
#       <td id="T_5fc24_row5_col3" class="data row5 col3" >-0.530</td>
#       <td id="T_5fc24_row5_col4" class="data row5 col4" >-0.084</td>
#       <td id="T_5fc24_row5_col5" class="data row5 col5" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# =============================================================
#                       Open Volatility After 10days Volatility
# -------------------------------------------------------------
# const                 0.000           -0.000
#                       (0.188)         (0.222)
# Surprise(%)           0.252           0.129
#                       (0.226)         (0.173)
# Volatility_before_10d -0.553***       -0.096
#                       (0.211)         (0.252)
# R-squared             0.344           0.024
# R-squared Adj.        0.281           -0.069
# =============================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Volatility_open   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     4.834
# Date:                Tue, 10 Mar 2026   Prob (F-statistic):             0.0188
# Time:                        03:06:34   Log-Likelihood:                -28.487
# No. Observations:                  24   AIC:                             62.97
# Df Residuals:                      21   BIC:                             66.51
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  2.776e-17      0.188   1.48e-16      1.000      -0.368       0.368
# Surprise(%)               0.2517      0.226      1.113      0.266      -0.192       0.695
# Volatility_before_10d    -0.5525      0.211     -2.619      0.009      -0.966      -0.139
# ==============================================================================
# Omnibus:                        0.980   Durbin-Watson:                   2.283
# Prob(Omnibus):                  0.613   Jarque-Bera (JB):                0.959
# Skew:                           0.358   Prob(JB):                        0.619
# Kurtosis:                       2.332   Cond. No.                         1.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Volatility_after_10d   R-squared:                       0.024
# Model:                              OLS   Adj. R-squared:                 -0.069
# Method:                   Least Squares   F-statistic:                    0.3190
# Date:                  Tue, 10 Mar 2026   Prob (F-statistic):              0.730
# Time:                          03:06:34   Log-Likelihood:                -33.256
# No. Observations:                    24   AIC:                             72.51
# Df Residuals:                        21   BIC:                             76.05
# Df Model:                             2
# Covariance Type:                    HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -4.163e-17      0.222  -1.87e-16      1.000      -0.436       0.436
# Surprise(%)               0.1292      0.173      0.746      0.456      -0.210       0.469
# Volatility_before_10d    -0.0960      0.252     -0.381      0.703      -0.590       0.398
# ==============================================================================
# Omnibus:                        0.007   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.996   Jarque-Bera (JB):                0.114
# Skew:                          -0.002   Prob(JB):                        0.945
# Kurtosis:                       2.663   Cond. No.                         1.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [*********************100%***********************]  1 of 1 completed
# <style type="text/css">
# #T_5066a_row0_col0, #T_5066a_row1_col1, #T_5066a_row2_col2, #T_5066a_row3_col3, #T_5066a_row4_col4, #T_5066a_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5066a_row0_col1, #T_5066a_row1_col0, #T_5066a_row1_col4, #T_5066a_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5066a_row0_col2, #T_5066a_row2_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_5066a_row0_col3, #T_5066a_row3_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5066a_row0_col4, #T_5066a_row1_col2, #T_5066a_row2_col1, #T_5066a_row4_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5066a_row0_col5, #T_5066a_row5_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_5066a_row1_col3, #T_5066a_row3_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_5066a_row1_col5, #T_5066a_row5_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_5066a_row2_col3, #T_5066a_row3_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_5066a_row2_col4, #T_5066a_row4_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_5066a_row2_col5, #T_5066a_row5_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5066a_row3_col4, #T_5066a_row4_col3 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_5066a_row3_col5, #T_5066a_row5_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_5066a_row4_col5, #T_5066a_row5_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# </style>
# <table id="T_5066a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5066a_level0_col0" class="col_heading level0 col0" >Surprise(%)</th>
#       <th id="T_5066a_level0_col1" class="col_heading level0 col1" >EPS Estimate</th>
#       <th id="T_5066a_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_5066a_level0_col3" class="col_heading level0 col3" >Volatility_open</th>
#       <th id="T_5066a_level0_col4" class="col_heading level0 col4" >Volatility_after_10d</th>
#       <th id="T_5066a_level0_col5" class="col_heading level0 col5" >Volatility_before_10d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5066a_level0_row0" class="row_heading level0 row0" >Surprise(%)</th>
#       <td id="T_5066a_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_5066a_row0_col1" class="data row0 col1" >-0.087</td>
#       <td id="T_5066a_row0_col2" class="data row0 col2" >-0.165</td>
#       <td id="T_5066a_row0_col3" class="data row0 col3" >-0.113</td>
#       <td id="T_5066a_row0_col4" class="data row0 col4" >-0.136</td>
#       <td id="T_5066a_row0_col5" class="data row0 col5" >0.207</td>
#     </tr>
#     <tr>
#       <th id="T_5066a_level0_row1" class="row_heading level0 row1" >EPS Estimate</th>
#       <td id="T_5066a_row1_col0" class="data row1 col0" >-0.087</td>
#       <td id="T_5066a_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_5066a_row1_col2" class="data row1 col2" >-0.138</td>
#       <td id="T_5066a_row1_col3" class="data row1 col3" >-0.075</td>
#       <td id="T_5066a_row1_col4" class="data row1 col4" >-0.090</td>
#       <td id="T_5066a_row1_col5" class="data row1 col5" >0.299</td>
#     </tr>
#     <tr>
#       <th id="T_5066a_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_5066a_row2_col0" class="data row2 col0" >-0.165</td>
#       <td id="T_5066a_row2_col1" class="data row2 col1" >-0.138</td>
#       <td id="T_5066a_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_5066a_row2_col3" class="data row2 col3" >0.935</td>
#       <td id="T_5066a_row2_col4" class="data row2 col4" >0.375</td>
#       <td id="T_5066a_row2_col5" class="data row2 col5" >-0.851</td>
#     </tr>
#     <tr>
#       <th id="T_5066a_level0_row3" class="row_heading level0 row3" >Volatility_open</th>
#       <td id="T_5066a_row3_col0" class="data row3 col0" >-0.113</td>
#       <td id="T_5066a_row3_col1" class="data row3 col1" >-0.075</td>
#       <td id="T_5066a_row3_col2" class="data row3 col2" >0.935</td>
#       <td id="T_5066a_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_5066a_row3_col4" class="data row3 col4" >0.465</td>
#       <td id="T_5066a_row3_col5" class="data row3 col5" >-0.778</td>
#     </tr>
#     <tr>
#       <th id="T_5066a_level0_row4" class="row_heading level0 row4" >Volatility_after_10d</th>
#       <td id="T_5066a_row4_col0" class="data row4 col0" >-0.136</td>
#       <td id="T_5066a_row4_col1" class="data row4 col1" >-0.090</td>
#       <td id="T_5066a_row4_col2" class="data row4 col2" >0.375</td>
#       <td id="T_5066a_row4_col3" class="data row4 col3" >0.465</td>
#       <td id="T_5066a_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_5066a_row4_col5" class="data row4 col5" >-0.239</td>
#     </tr>
#     <tr>
#       <th id="T_5066a_level0_row5" class="row_heading level0 row5" >Volatility_before_10d</th>
#       <td id="T_5066a_row5_col0" class="data row5 col0" >0.207</td>
#       <td id="T_5066a_row5_col1" class="data row5 col1" >0.299</td>
#       <td id="T_5066a_row5_col2" class="data row5 col2" >-0.851</td>
#       <td id="T_5066a_row5_col3" class="data row5 col3" >-0.778</td>
#       <td id="T_5066a_row5_col4" class="data row5 col4" >-0.239</td>
#       <td id="T_5066a_row5_col5" class="data row5 col5" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# =============================================================
#                       Open Volatility After 10days Volatility
# -------------------------------------------------------------
# const                 -0.000          -0.000
#                       (0.142)         (0.224)
# Surprise(%)           0.050           -0.091
#                       (0.151)         (0.276)
# Volatility_before_10d -0.788***       -0.220
#                       (0.130)         (0.242)
# R-squared             0.607           0.065
# R-squared Adj.        0.570           -0.024
# =============================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Volatility_open   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     18.47
# Date:                Tue, 10 Mar 2026   Prob (F-statistic):           2.36e-05
# Time:                        03:06:35   Log-Likelihood:                -22.333
# No. Observations:                  24   AIC:                             50.67
# Df Residuals:                      21   BIC:                             54.20
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -2.776e-17      0.142  -1.96e-16      1.000      -0.278       0.278
# Surprise(%)               0.0505      0.151      0.334      0.739      -0.246       0.347
# Volatility_before_10d    -0.7881      0.130     -6.077      0.000      -1.042      -0.534
# ==============================================================================
# Omnibus:                        2.559   Durbin-Watson:                   1.605
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                1.147
# Skew:                          -0.070   Prob(JB):                        0.564
# Kurtosis:                       4.062   Cond. No.                         1.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Volatility_after_10d   R-squared:                       0.065
# Model:                              OLS   Adj. R-squared:                 -0.024
# Method:                   Least Squares   F-statistic:                    0.5700
# Date:                  Tue, 10 Mar 2026   Prob (F-statistic):              0.574
# Time:                          03:06:35   Log-Likelihood:                -32.736
# No. Observations:                    24   AIC:                             71.47
# Df Residuals:                        21   BIC:                             75.01
# Df Model:                             2
# Covariance Type:                    HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -3.123e-17      0.224   -1.4e-16      1.000      -0.438       0.438
# Surprise(%)              -0.0905      0.276     -0.328      0.743      -0.631       0.450
# Volatility_before_10d    -0.2205      0.242     -0.910      0.363      -0.695       0.254
# ==============================================================================
# Omnibus:                        1.653   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.438   Jarque-Bera (JB):                1.425
# Skew:                           0.465   Prob(JB):                        0.490
# Kurtosis:                       2.253   Cond. No.                         1.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [*********************100%***********************]  1 of 1 completed
# <style type="text/css">
# #T_1d27e_row0_col0, #T_1d27e_row1_col1, #T_1d27e_row2_col2, #T_1d27e_row3_col3, #T_1d27e_row4_col4, #T_1d27e_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1d27e_row0_col1, #T_1d27e_row1_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_1d27e_row0_col2, #T_1d27e_row2_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_1d27e_row0_col3, #T_1d27e_row3_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_1d27e_row0_col4, #T_1d27e_row4_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_1d27e_row0_col5, #T_1d27e_row5_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_1d27e_row1_col2, #T_1d27e_row2_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1d27e_row1_col3, #T_1d27e_row3_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1d27e_row1_col4, #T_1d27e_row4_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1d27e_row1_col5, #T_1d27e_row5_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_1d27e_row2_col3, #T_1d27e_row3_col2 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_1d27e_row2_col4, #T_1d27e_row4_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_1d27e_row2_col5, #T_1d27e_row5_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1d27e_row3_col4, #T_1d27e_row4_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_1d27e_row3_col5, #T_1d27e_row5_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1d27e_row4_col5, #T_1d27e_row5_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# </style>
# <table id="T_1d27e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d27e_level0_col0" class="col_heading level0 col0" >Surprise(%)</th>
#       <th id="T_1d27e_level0_col1" class="col_heading level0 col1" >EPS Estimate</th>
#       <th id="T_1d27e_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_1d27e_level0_col3" class="col_heading level0 col3" >Volatility_open</th>
#       <th id="T_1d27e_level0_col4" class="col_heading level0 col4" >Volatility_after_10d</th>
#       <th id="T_1d27e_level0_col5" class="col_heading level0 col5" >Volatility_before_10d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d27e_level0_row0" class="row_heading level0 row0" >Surprise(%)</th>
#       <td id="T_1d27e_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_1d27e_row0_col1" class="data row0 col1" >-0.262</td>
#       <td id="T_1d27e_row0_col2" class="data row0 col2" >0.396</td>
#       <td id="T_1d27e_row0_col3" class="data row0 col3" >0.480</td>
#       <td id="T_1d27e_row0_col4" class="data row0 col4" >-0.039</td>
#       <td id="T_1d27e_row0_col5" class="data row0 col5" >-0.419</td>
#     </tr>
#     <tr>
#       <th id="T_1d27e_level0_row1" class="row_heading level0 row1" >EPS Estimate</th>
#       <td id="T_1d27e_row1_col0" class="data row1 col0" >-0.262</td>
#       <td id="T_1d27e_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_1d27e_row1_col2" class="data row1 col2" >-0.249</td>
#       <td id="T_1d27e_row1_col3" class="data row1 col3" >-0.256</td>
#       <td id="T_1d27e_row1_col4" class="data row1 col4" >-0.150</td>
#       <td id="T_1d27e_row1_col5" class="data row1 col5" >0.371</td>
#     </tr>
#     <tr>
#       <th id="T_1d27e_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_1d27e_row2_col0" class="data row2 col0" >0.396</td>
#       <td id="T_1d27e_row2_col1" class="data row2 col1" >-0.249</td>
#       <td id="T_1d27e_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_1d27e_row2_col3" class="data row2 col3" >0.919</td>
#       <td id="T_1d27e_row2_col4" class="data row2 col4" >0.203</td>
#       <td id="T_1d27e_row2_col5" class="data row2 col5" >-0.818</td>
#     </tr>
#     <tr>
#       <th id="T_1d27e_level0_row3" class="row_heading level0 row3" >Volatility_open</th>
#       <td id="T_1d27e_row3_col0" class="data row3 col0" >0.480</td>
#       <td id="T_1d27e_row3_col1" class="data row3 col1" >-0.256</td>
#       <td id="T_1d27e_row3_col2" class="data row3 col2" >0.919</td>
#       <td id="T_1d27e_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_1d27e_row3_col4" class="data row3 col4" >0.122</td>
#       <td id="T_1d27e_row3_col5" class="data row3 col5" >-0.825</td>
#     </tr>
#     <tr>
#       <th id="T_1d27e_level0_row4" class="row_heading level0 row4" >Volatility_after_10d</th>
#       <td id="T_1d27e_row4_col0" class="data row4 col0" >-0.039</td>
#       <td id="T_1d27e_row4_col1" class="data row4 col1" >-0.150</td>
#       <td id="T_1d27e_row4_col2" class="data row4 col2" >0.203</td>
#       <td id="T_1d27e_row4_col3" class="data row4 col3" >0.122</td>
#       <td id="T_1d27e_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_1d27e_row4_col5" class="data row4 col5" >-0.233</td>
#     </tr>
#     <tr>
#       <th id="T_1d27e_level0_row5" class="row_heading level0 row5" >Volatility_before_10d</th>
#       <td id="T_1d27e_row5_col0" class="data row5 col0" >-0.419</td>
#       <td id="T_1d27e_row5_col1" class="data row5 col1" >0.371</td>
#       <td id="T_1d27e_row5_col2" class="data row5 col2" >-0.818</td>
#       <td id="T_1d27e_row5_col3" class="data row5 col3" >-0.825</td>
#       <td id="T_1d27e_row5_col4" class="data row5 col4" >-0.233</td>
#       <td id="T_1d27e_row5_col5" class="data row5 col5" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# =============================================================
#                       Open Volatility After 10days Volatility
# -------------------------------------------------------------
# const                 0.000           0.000
#                       (0.119)         (0.223)
# Surprise(%)           0.163*          -0.166
#                       (0.085)         (0.255)
# Volatility_before_10d -0.757***       -0.303
#                       (0.110)         (0.283)
# R-squared             0.703           0.077
# R-squared Adj.        0.675           -0.011
# =============================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Volatility_open   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.675
# Method:                 Least Squares   F-statistic:                     37.15
# Date:                Tue, 10 Mar 2026   Prob (F-statistic):           1.27e-07
# Time:                        03:06:36   Log-Likelihood:                -18.967
# No. Observations:                  24   AIC:                             43.93
# Df Residuals:                      21   BIC:                             47.47
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.388e-17      0.119   1.17e-16      1.000      -0.233       0.233
# Surprise(%)               0.1626      0.085      1.915      0.056      -0.004       0.329
# Volatility_before_10d    -0.7573      0.110     -6.882      0.000      -0.973      -0.542
# ==============================================================================
# Omnibus:                        2.427   Durbin-Watson:                   2.434
# Prob(Omnibus):                  0.297   Jarque-Bera (JB):                1.215
# Skew:                           0.521   Prob(JB):                        0.545
# Kurtosis:                       3.360   Cond. No.                         1.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Volatility_after_10d   R-squared:                       0.077
# Model:                              OLS   Adj. R-squared:                 -0.011
# Method:                   Least Squares   F-statistic:                    0.6273
# Date:                  Tue, 10 Mar 2026   Prob (F-statistic):              0.544
# Time:                          03:06:36   Log-Likelihood:                -32.583
# No. Observations:                    24   AIC:                             71.17
# Df Residuals:                        21   BIC:                             74.70
# Df Model:                             2
# Covariance Type:                    HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  5.551e-17      0.223   2.49e-16      1.000      -0.437       0.437
# Surprise(%)              -0.1659      0.255     -0.652      0.515      -0.665       0.333
# Volatility_before_10d    -0.3025      0.283     -1.071      0.284      -0.856       0.251
# ==============================================================================
# Omnibus:                        0.198   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.906   Jarque-Bera (JB):                0.009
# Skew:                           0.014   Prob(JB):                        0.995
# Kurtosis:                       2.909   Cond. No.                         1.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [*********************100%***********************]  1 of 1 completed
# <style type="text/css">
# #T_e2725_row0_col0, #T_e2725_row1_col1, #T_e2725_row2_col2, #T_e2725_row3_col3, #T_e2725_row4_col4, #T_e2725_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e2725_row0_col1, #T_e2725_row1_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e2725_row0_col2, #T_e2725_row2_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_e2725_row0_col3, #T_e2725_row3_col0 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_e2725_row0_col4, #T_e2725_row4_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_e2725_row0_col5, #T_e2725_row5_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e2725_row1_col2, #T_e2725_row2_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e2725_row1_col3, #T_e2725_row3_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e2725_row1_col4, #T_e2725_row4_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_e2725_row1_col5, #T_e2725_row5_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_e2725_row2_col3, #T_e2725_row3_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_e2725_row2_col4, #T_e2725_row4_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_e2725_row2_col5, #T_e2725_row5_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e2725_row3_col4, #T_e2725_row4_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_e2725_row3_col5, #T_e2725_row5_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e2725_row4_col5, #T_e2725_row5_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_e2725" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2725_level0_col0" class="col_heading level0 col0" >Surprise(%)</th>
#       <th id="T_e2725_level0_col1" class="col_heading level0 col1" >EPS Estimate</th>
#       <th id="T_e2725_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_e2725_level0_col3" class="col_heading level0 col3" >Volatility_open</th>
#       <th id="T_e2725_level0_col4" class="col_heading level0 col4" >Volatility_after_10d</th>
#       <th id="T_e2725_level0_col5" class="col_heading level0 col5" >Volatility_before_10d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2725_level0_row0" class="row_heading level0 row0" >Surprise(%)</th>
#       <td id="T_e2725_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_e2725_row0_col1" class="data row0 col1" >-0.192</td>
#       <td id="T_e2725_row0_col2" class="data row0 col2" >0.385</td>
#       <td id="T_e2725_row0_col3" class="data row0 col3" >0.376</td>
#       <td id="T_e2725_row0_col4" class="data row0 col4" >0.310</td>
#       <td id="T_e2725_row0_col5" class="data row0 col5" >-0.299</td>
#     </tr>
#     <tr>
#       <th id="T_e2725_level0_row1" class="row_heading level0 row1" >EPS Estimate</th>
#       <td id="T_e2725_row1_col0" class="data row1 col0" >-0.192</td>
#       <td id="T_e2725_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_e2725_row1_col2" class="data row1 col2" >-0.056</td>
#       <td id="T_e2725_row1_col3" class="data row1 col3" >-0.101</td>
#       <td id="T_e2725_row1_col4" class="data row1 col4" >0.101</td>
#       <td id="T_e2725_row1_col5" class="data row1 col5" >-0.081</td>
#     </tr>
#     <tr>
#       <th id="T_e2725_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_e2725_row2_col0" class="data row2 col0" >0.385</td>
#       <td id="T_e2725_row2_col1" class="data row2 col1" >-0.056</td>
#       <td id="T_e2725_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_e2725_row2_col3" class="data row2 col3" >0.956</td>
#       <td id="T_e2725_row2_col4" class="data row2 col4" >0.107</td>
#       <td id="T_e2725_row2_col5" class="data row2 col5" >-0.807</td>
#     </tr>
#     <tr>
#       <th id="T_e2725_level0_row3" class="row_heading level0 row3" >Volatility_open</th>
#       <td id="T_e2725_row3_col0" class="data row3 col0" >0.376</td>
#       <td id="T_e2725_row3_col1" class="data row3 col1" >-0.101</td>
#       <td id="T_e2725_row3_col2" class="data row3 col2" >0.956</td>
#       <td id="T_e2725_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_e2725_row3_col4" class="data row3 col4" >0.042</td>
#       <td id="T_e2725_row3_col5" class="data row3 col5" >-0.754</td>
#     </tr>
#     <tr>
#       <th id="T_e2725_level0_row4" class="row_heading level0 row4" >Volatility_after_10d</th>
#       <td id="T_e2725_row4_col0" class="data row4 col0" >0.310</td>
#       <td id="T_e2725_row4_col1" class="data row4 col1" >0.101</td>
#       <td id="T_e2725_row4_col2" class="data row4 col2" >0.107</td>
#       <td id="T_e2725_row4_col3" class="data row4 col3" >0.042</td>
#       <td id="T_e2725_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_e2725_row4_col5" class="data row4 col5" >0.002</td>
#     </tr>
#     <tr>
#       <th id="T_e2725_level0_row5" class="row_heading level0 row5" >Volatility_before_10d</th>
#       <td id="T_e2725_row5_col0" class="data row5 col0" >-0.299</td>
#       <td id="T_e2725_row5_col1" class="data row5 col1" >-0.081</td>
#       <td id="T_e2725_row5_col2" class="data row5 col2" >-0.807</td>
#       <td id="T_e2725_row5_col3" class="data row5 col3" >-0.754</td>
#       <td id="T_e2725_row5_col4" class="data row5 col4" >0.002</td>
#       <td id="T_e2725_row5_col5" class="data row5 col5" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# =============================================================
#                       Open Volatility After 10days Volatility
# -------------------------------------------------------------
# const                 0.000           0.000
#                       (0.155)         (0.239)
# Surprise(%)           0.165           0.341
#                       (0.158)         (0.290)
# Volatility_before_10d -0.704***       0.104
#                       (0.268)         (0.422)
# R-squared             0.593           0.106
# R-squared Adj.        0.554           0.021
# =============================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Volatility_open   R-squared:                       0.593
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     4.404
# Date:                Tue, 10 Mar 2026   Prob (F-statistic):             0.0253
# Time:                        03:06:37   Log-Likelihood:                -22.762
# No. Observations:                  24   AIC:                             51.52
# Df Residuals:                      21   BIC:                             55.06
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  5.551e-17      0.155   3.58e-16      1.000      -0.304       0.304
# Surprise(%)               0.1652      0.158      1.047      0.295      -0.144       0.474
# Volatility_before_10d    -0.7043      0.268     -2.630      0.009      -1.229      -0.179
# ==============================================================================
# Omnibus:                        1.318   Durbin-Watson:                   2.418
# Prob(Omnibus):                  0.517   Jarque-Bera (JB):                0.956
# Skew:                           0.178   Prob(JB):                        0.620
# Kurtosis:                       2.089   Cond. No.                         1.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Volatility_after_10d   R-squared:                       0.106
# Model:                              OLS   Adj. R-squared:                  0.021
# Method:                   Least Squares   F-statistic:                    0.7264
# Date:                  Tue, 10 Mar 2026   Prob (F-statistic):              0.495
# Time:                          03:06:37   Log-Likelihood:                -32.201
# No. Observations:                    24   AIC:                             70.40
# Df Residuals:                        21   BIC:                             73.94
# Df Model:                             2
# Covariance Type:                    HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                          0      0.239          0      1.000      -0.468       0.468
# Surprise(%)               0.3410      0.290      1.176      0.239      -0.227       0.909
# Volatility_before_10d     0.1036      0.422      0.245      0.806      -0.724       0.932
# ==============================================================================
# Omnibus:                        1.200   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.549   Jarque-Bera (JB):                0.264
# Skew:                          -0.146   Prob(JB):                        0.876
# Kurtosis:                       3.422   Cond. No.                         1.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [*********************100%***********************]  1 of 1 completed
# <style type="text/css">
# #T_cee3e_row0_col0, #T_cee3e_row1_col1, #T_cee3e_row2_col2, #T_cee3e_row3_col3, #T_cee3e_row4_col4, #T_cee3e_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cee3e_row0_col1, #T_cee3e_row1_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_cee3e_row0_col2, #T_cee3e_row2_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_cee3e_row0_col3, #T_cee3e_row3_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_cee3e_row0_col4, #T_cee3e_row4_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_cee3e_row0_col5, #T_cee3e_row5_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_cee3e_row1_col2, #T_cee3e_row2_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_cee3e_row1_col3, #T_cee3e_row1_col5, #T_cee3e_row3_col1, #T_cee3e_row5_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_cee3e_row1_col4, #T_cee3e_row4_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_cee3e_row2_col3, #T_cee3e_row3_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_cee3e_row2_col4, #T_cee3e_row4_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_cee3e_row2_col5, #T_cee3e_row5_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_cee3e_row3_col4, #T_cee3e_row4_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_cee3e_row3_col5, #T_cee3e_row5_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_cee3e_row4_col5, #T_cee3e_row5_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_cee3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cee3e_level0_col0" class="col_heading level0 col0" >Surprise(%)</th>
#       <th id="T_cee3e_level0_col1" class="col_heading level0 col1" >EPS Estimate</th>
#       <th id="T_cee3e_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_cee3e_level0_col3" class="col_heading level0 col3" >Volatility_open</th>
#       <th id="T_cee3e_level0_col4" class="col_heading level0 col4" >Volatility_after_10d</th>
#       <th id="T_cee3e_level0_col5" class="col_heading level0 col5" >Volatility_before_10d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cee3e_level0_row0" class="row_heading level0 row0" >Surprise(%)</th>
#       <td id="T_cee3e_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_cee3e_row0_col1" class="data row0 col1" >-0.231</td>
#       <td id="T_cee3e_row0_col2" class="data row0 col2" >0.211</td>
#       <td id="T_cee3e_row0_col3" class="data row0 col3" >0.274</td>
#       <td id="T_cee3e_row0_col4" class="data row0 col4" >0.117</td>
#       <td id="T_cee3e_row0_col5" class="data row0 col5" >-0.399</td>
#     </tr>
#     <tr>
#       <th id="T_cee3e_level0_row1" class="row_heading level0 row1" >EPS Estimate</th>
#       <td id="T_cee3e_row1_col0" class="data row1 col0" >-0.231</td>
#       <td id="T_cee3e_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_cee3e_row1_col2" class="data row1 col2" >0.016</td>
#       <td id="T_cee3e_row1_col3" class="data row1 col3" >0.011</td>
#       <td id="T_cee3e_row1_col4" class="data row1 col4" >-0.203</td>
#       <td id="T_cee3e_row1_col5" class="data row1 col5" >0.015</td>
#     </tr>
#     <tr>
#       <th id="T_cee3e_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_cee3e_row2_col0" class="data row2 col0" >0.211</td>
#       <td id="T_cee3e_row2_col1" class="data row2 col1" >0.016</td>
#       <td id="T_cee3e_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_cee3e_row2_col3" class="data row2 col3" >0.979</td>
#       <td id="T_cee3e_row2_col4" class="data row2 col4" >0.047</td>
#       <td id="T_cee3e_row2_col5" class="data row2 col5" >-0.833</td>
#     </tr>
#     <tr>
#       <th id="T_cee3e_level0_row3" class="row_heading level0 row3" >Volatility_open</th>
#       <td id="T_cee3e_row3_col0" class="data row3 col0" >0.274</td>
#       <td id="T_cee3e_row3_col1" class="data row3 col1" >0.011</td>
#       <td id="T_cee3e_row3_col2" class="data row3 col2" >0.979</td>
#       <td id="T_cee3e_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_cee3e_row3_col4" class="data row3 col4" >0.028</td>
#       <td id="T_cee3e_row3_col5" class="data row3 col5" >-0.852</td>
#     </tr>
#     <tr>
#       <th id="T_cee3e_level0_row4" class="row_heading level0 row4" >Volatility_after_10d</th>
#       <td id="T_cee3e_row4_col0" class="data row4 col0" >0.117</td>
#       <td id="T_cee3e_row4_col1" class="data row4 col1" >-0.203</td>
#       <td id="T_cee3e_row4_col2" class="data row4 col2" >0.047</td>
#       <td id="T_cee3e_row4_col3" class="data row4 col3" >0.028</td>
#       <td id="T_cee3e_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_cee3e_row4_col5" class="data row4 col5" >-0.006</td>
#     </tr>
#     <tr>
#       <th id="T_cee3e_level0_row5" class="row_heading level0 row5" >Volatility_before_10d</th>
#       <td id="T_cee3e_row5_col0" class="data row5 col0" >-0.399</td>
#       <td id="T_cee3e_row5_col1" class="data row5 col1" >0.015</td>
#       <td id="T_cee3e_row5_col2" class="data row5 col2" >-0.833</td>
#       <td id="T_cee3e_row5_col3" class="data row5 col3" >-0.852</td>
#       <td id="T_cee3e_row5_col4" class="data row5 col4" >-0.006</td>
#       <td id="T_cee3e_row5_col5" class="data row5 col5" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# =============================================================
#                       Open Volatility After 10days Volatility
# -------------------------------------------------------------
# const                 -0.000          -0.000
#                       (0.124)         (0.214)
# Surprise(%)           -0.080          0.136
#                       (0.110)         (0.165)
# Volatility_before_10d -0.884***       0.048
#                       (0.249)         (0.159)
# R-squared             0.732           0.016
# R-squared Adj.        0.706           -0.078
# =============================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Volatility_open   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     9.765
# Date:                Tue, 10 Mar 2026   Prob (F-statistic):            0.00100
# Time:                        03:06:38   Log-Likelihood:                -17.756
# No. Observations:                  24   AIC:                             41.51
# Df Residuals:                      21   BIC:                             45.05
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -5.551e-17      0.124  -4.46e-16      1.000      -0.244       0.244
# Surprise(%)              -0.0796      0.110     -0.724      0.469      -0.295       0.136
# Volatility_before_10d    -0.8841      0.249     -3.551      0.000      -1.372      -0.396
# ==============================================================================
# Omnibus:                        0.855   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.652   Jarque-Bera (JB):                0.856
# Skew:                          -0.373   Prob(JB):                        0.652
# Kurtosis:                       2.453   Cond. No.                         1.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Volatility_after_10d   R-squared:                       0.016
# Model:                              OLS   Adj. R-squared:                 -0.078
# Method:                   Least Squares   F-statistic:                    0.5297
# Date:                  Tue, 10 Mar 2026   Prob (F-statistic):              0.596
# Time:                          03:06:38   Log-Likelihood:                -33.356
# No. Observations:                    24   AIC:                             72.71
# Df Residuals:                        21   BIC:                             76.25
# Df Model:                             2
# Covariance Type:                    HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -2.776e-17      0.214   -1.3e-16      1.000      -0.419       0.419
# Surprise(%)               0.1358      0.165      0.821      0.412      -0.188       0.460
# Volatility_before_10d     0.0479      0.159      0.301      0.763      -0.264       0.359
# ==============================================================================
# Omnibus:                       16.741   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.027
# Skew:                           1.486   Prob(JB):                     4.48e-05
# Kurtosis:                       6.345   Cond. No.                         1.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [*********************100%***********************]  1 of 1 completed
# <style type="text/css">
# #T_3703b_row0_col0, #T_3703b_row1_col1, #T_3703b_row2_col2, #T_3703b_row3_col3, #T_3703b_row4_col4, #T_3703b_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3703b_row0_col1, #T_3703b_row1_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_3703b_row0_col2, #T_3703b_row1_col4, #T_3703b_row2_col0, #T_3703b_row4_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_3703b_row0_col3, #T_3703b_row3_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_3703b_row0_col4, #T_3703b_row4_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_3703b_row0_col5, #T_3703b_row5_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_3703b_row1_col2, #T_3703b_row2_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_3703b_row1_col3, #T_3703b_row3_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_3703b_row1_col5, #T_3703b_row5_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_3703b_row2_col3, #T_3703b_row3_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_3703b_row2_col4, #T_3703b_row4_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_3703b_row2_col5, #T_3703b_row5_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_3703b_row3_col4, #T_3703b_row4_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3703b_row3_col5, #T_3703b_row5_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_3703b_row4_col5, #T_3703b_row5_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# </style>
# <table id="T_3703b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3703b_level0_col0" class="col_heading level0 col0" >Surprise(%)</th>
#       <th id="T_3703b_level0_col1" class="col_heading level0 col1" >EPS Estimate</th>
#       <th id="T_3703b_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_3703b_level0_col3" class="col_heading level0 col3" >Volatility_open</th>
#       <th id="T_3703b_level0_col4" class="col_heading level0 col4" >Volatility_after_10d</th>
#       <th id="T_3703b_level0_col5" class="col_heading level0 col5" >Volatility_before_10d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3703b_level0_row0" class="row_heading level0 row0" >Surprise(%)</th>
#       <td id="T_3703b_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_3703b_row0_col1" class="data row0 col1" >0.165</td>
#       <td id="T_3703b_row0_col2" class="data row0 col2" >0.027</td>
#       <td id="T_3703b_row0_col3" class="data row0 col3" >0.345</td>
#       <td id="T_3703b_row0_col4" class="data row0 col4" >0.137</td>
#       <td id="T_3703b_row0_col5" class="data row0 col5" >0.106</td>
#     </tr>
#     <tr>
#       <th id="T_3703b_level0_row1" class="row_heading level0 row1" >EPS Estimate</th>
#       <td id="T_3703b_row1_col0" class="data row1 col0" >0.165</td>
#       <td id="T_3703b_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_3703b_row1_col2" class="data row1 col2" >0.112</td>
#       <td id="T_3703b_row1_col3" class="data row1 col3" >0.237</td>
#       <td id="T_3703b_row1_col4" class="data row1 col4" >0.027</td>
#       <td id="T_3703b_row1_col5" class="data row1 col5" >-0.145</td>
#     </tr>
#     <tr>
#       <th id="T_3703b_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_3703b_row2_col0" class="data row2 col0" >0.027</td>
#       <td id="T_3703b_row2_col1" class="data row2 col1" >0.112</td>
#       <td id="T_3703b_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_3703b_row2_col3" class="data row2 col3" >0.592</td>
#       <td id="T_3703b_row2_col4" class="data row2 col4" >-0.237</td>
#       <td id="T_3703b_row2_col5" class="data row2 col5" >-0.645</td>
#     </tr>
#     <tr>
#       <th id="T_3703b_level0_row3" class="row_heading level0 row3" >Volatility_open</th>
#       <td id="T_3703b_row3_col0" class="data row3 col0" >0.345</td>
#       <td id="T_3703b_row3_col1" class="data row3 col1" >0.237</td>
#       <td id="T_3703b_row3_col2" class="data row3 col2" >0.592</td>
#       <td id="T_3703b_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_3703b_row3_col4" class="data row3 col4" >-0.076</td>
#       <td id="T_3703b_row3_col5" class="data row3 col5" >-0.459</td>
#     </tr>
#     <tr>
#       <th id="T_3703b_level0_row4" class="row_heading level0 row4" >Volatility_after_10d</th>
#       <td id="T_3703b_row4_col0" class="data row4 col0" >0.137</td>
#       <td id="T_3703b_row4_col1" class="data row4 col1" >0.027</td>
#       <td id="T_3703b_row4_col2" class="data row4 col2" >-0.237</td>
#       <td id="T_3703b_row4_col3" class="data row4 col3" >-0.076</td>
#       <td id="T_3703b_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_3703b_row4_col5" class="data row4 col5" >-0.081</td>
#     </tr>
#     <tr>
#       <th id="T_3703b_level0_row5" class="row_heading level0 row5" >Volatility_before_10d</th>
#       <td id="T_3703b_row5_col0" class="data row5 col0" >0.106</td>
#       <td id="T_3703b_row5_col1" class="data row5 col1" >-0.145</td>
#       <td id="T_3703b_row5_col2" class="data row5 col2" >-0.645</td>
#       <td id="T_3703b_row5_col3" class="data row5 col3" >-0.459</td>
#       <td id="T_3703b_row5_col4" class="data row5 col4" >-0.081</td>
#       <td id="T_3703b_row5_col5" class="data row5 col5" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# =============================================================
#                       Open Volatility After 10days Volatility
# -------------------------------------------------------------
# const                 -0.000          -0.000
#                       (0.180)         (0.221)
# Surprise(%)           0.398**         0.148
#                       (0.167)         (0.224)
# Volatility_before_10d -0.501***       -0.097
#                       (0.194)         (0.200)
# R-squared             0.368           0.028
# R-squared Adj.        0.308           -0.064
# =============================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Volatility_open   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     4.846
# Date:                Tue, 10 Mar 2026   Prob (F-statistic):             0.0186
# Time:                        03:06:39   Log-Likelihood:                -28.041
# No. Observations:                  24   AIC:                             62.08
# Df Residuals:                      21   BIC:                             65.62
# Df Model:                           2
# Covariance Type:                  HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -6.939e-18      0.180  -3.86e-17      1.000      -0.352       0.352
# Surprise(%)               0.3984      0.167      2.390      0.017       0.072       0.725
# Volatility_before_10d    -0.5013      0.194     -2.589      0.010      -0.881      -0.122
# ==============================================================================
# Omnibus:                        1.327   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.515   Jarque-Bera (JB):                0.316
# Skew:                           0.139   Prob(JB):                        0.854
# Kurtosis:                       3.489   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Volatility_after_10d   R-squared:                       0.028
# Model:                              OLS   Adj. R-squared:                 -0.064
# Method:                   Least Squares   F-statistic:                    0.2730
# Date:                  Tue, 10 Mar 2026   Prob (F-statistic):              0.764
# Time:                          03:06:39   Log-Likelihood:                -33.201
# No. Observations:                    24   AIC:                             72.40
# Df Residuals:                        21   BIC:                             75.94
# Df Model:                             2
# Covariance Type:                    HC3
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  -4.51e-17      0.221  -2.04e-16      1.000      -0.434       0.434
# Surprise(%)               0.1476      0.224      0.658      0.510      -0.292       0.587
# Volatility_before_10d    -0.0969      0.200     -0.484      0.628      -0.489       0.295
# ==============================================================================
# Omnibus:                        1.276   Durbin-Watson:                   2.623
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                1.172
# Skew:                           0.466   Prob(JB):                        0.557
# Kurtosis:                       2.451   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
